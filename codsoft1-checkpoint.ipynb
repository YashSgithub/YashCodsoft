# %%
tasks = {}


def add_task():
    task = input("Enter the task: ")
    tasks[task] = False
    print(f"Task '{task}' added successfully!")


def view_tasks():
    if tasks:
        print("\n--- To-Do List ---")
        for task, completed in tasks.items():
            status = "Completed" if completed else "Not Completed"
            print(f"{task}: {status}")
    else:
        print("Your To-Do list is empty!")


def mark_completed():
    task = input("Enter the task to mark as completed: ")
    if task in tasks:
        tasks[task] = True
        print(f"Task '{task}' marked as completed!")
    else:
        print(f"Task '{task}' not found in your To-Do list.")

# Main loop
while True:
    print("\nOptions:")
    print("1. Add Task")
    print("2. View Tasks")
    print("3. Mark Task as Completed")
    print("4. Exit")

    choice = input("Enter your choice (1/2/3/4): ")

    if choice == '1':
        add_task()
    elif choice == '2':
        view_tasks()
    elif choice == '3':
        mark_completed()
    elif choice == '4':
        print("Exiting To-Do List application. Have a great day!")
        break
    else:
        print("Invalid choice. Please select a valid option.")
# Out:
# Options:
# 1. Add Task
# 2. View Tasks
# 3. Mark Task as Completed
# 4. Exit
# Enter your choice (1/2/3/4): 1
# Enter the task: Go to college
# Task 'Go to college' added successfully!
#
# Options:
# 1. Add Task
# 2. View Tasks
# 3. Mark Task as Completed
# 4. Exit
# Enter your choice (1/2/3/4): 1
# Invalid choice. Please select a valid option.
#
# Options:
# 1. Add Task
# 2. View Tasks
# 3. Mark Task as Completed
# 4. Exit
# Enter your choice (1/2/3/4): write assignment
# Invalid choice. Please select a valid option.
#
# Options:
# 1. Add Task
# 2. View Tasks
# 3. Mark Task as Completed
# 4. Exit
# Enter your choice (1/2/3/4): 1
# Enter the task: write assignment
# Task 'write assignment' added successfully!
#
# Options:
# 1. Add Task
# 2. View Tasks
# 3. Mark Task as Completed
# 4. Exit
# Enter your choice (1/2/3/4): 2
#
# --- To-Do List ---
# Go to college: Not Completed
# write assignment: Not Completed
#
# Options:
# 1. Add Task
# 2. View Tasks
# 3. Mark Task as Completed
# 4. Exit
# Enter your choice (1/2/3/4): 3
# Enter the task to mark as completed: go to college
# Task 'go to college' not found in your To-Do list.
#
# Options:
# 1. Add Task
# 2. View Tasks
# 3. Mark Task as Completed
# 4. Exit
# Enter your choice (1/2/3/4): 1
# Enter the task:
# Task '' added successfully!
#
# Options:
# 1. Add Task
# 2. View Tasks
# 3. Mark Task as Completed
# 4. Exit
# Enter your choice (1/2/3/4): 3
# Enter the task to mark as completed: 1
# Task '1' not found in your To-Do list.
#
# Options:
# 1. Add Task
# 2. View Tasks
# 3. Mark Task as Completed
# 4. Exit
